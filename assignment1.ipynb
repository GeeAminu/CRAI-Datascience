# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
data = pd.read_csv("/home/salim/Desktop/CRAI/Data/iris_dataset/iris.dataCopy.csv")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.hist(figsize=(3,6))
plt.show()

# %%
sbn.boxplot(data=data,x="sepal_length", y="petal_width")
plt.show()

# %%
sbn.scatterplot(data=data, x="sepal_length", y="petal_width", hue="species")
plt.show()

# %%
sbn.heatmap(data.corr(), annot=True)
plt.show()

# %%
sbn.barplot(data=data, x="sepal_length", y="petal_width")
plt.show()

# %%
plt.pie(data['species'].value_counts(), labels=data["species"].unique())
plt.show()
